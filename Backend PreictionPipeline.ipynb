# %% [markdown]
# ### PreProcess Data

# %%
import requests
import pandas as pd
import numpy as np 
# Fetch the data from FastAPI
response = requests.get("http://localhost:8000/get_data/")
if response.status_code == 200:
    data = response.json()
    dataframe = pd.DataFrame(data)
    display(dataframe)
else:
    print("Failed to retrieve data")
# Out:
#    Number of Buildings  Bathrooms  Square Footage  Number of Units  \
# 0                    3          2             447                2
#
#                Property Type  Median Income  Housing Cost (%)  Building Age  \
# 0  Single Family Residential            324                40            71
#
#    Improvement Value
# 0                432

# %%
dataframe
# Out:
#    Number of Buildings  Bathrooms  Square Footage  Number of Units  \
# 0                    3          2             447                2
#
#                Property Type  Median Income  Housing Cost (%)  Building Age  \
# 0  Single Family Residential            324                40            71
#
#    Improvement Value
# 0                432

# %%
def map_property_type(df, column_name="Property Type"):
    mapping = {
        "Single Family Residential": 3,
        "Low Density Residential": 2,
        "Condominium": 1
    }
    df["Property Type"] = df[column_name].map(mapping)
    df['Log_Improvement_Value'] = np.log1p(df['Improvement Value'])
    df['Log_Square_Footage'] = np.log1p(df['Square Footage'])

    return df

# %%
dataframe=map_property_type(dataframe)

test_data= pd.read_csv("data/LA Prices 2019-2023 and Census.csv")

# %%
sample = test_data[['Zip Code','Roll Year']]

sample_df=sample.groupby("Zip Code").mean().reset_index()
sample_df
# Out:
#      Zip Code    Roll Year
# 0       90001  2021.011143
# 1       90002  2021.008335
# 2       90003  2021.008422
# 3       90004  2021.002186
# 4       90005  2021.037239
# ..        ...          ...
# 276     93551  2021.006554
# 277     93552  2021.008169
# 278     93553  2021.024806
# 279     93563  2020.520833
# 280     93591  2021.008736
#
# [281 rows x 2 columns]

# %%
repeated_df = pd.concat([dataframe]*len(sample_df), ignore_index=True)

# Concatenate along columns
combined = pd.concat([sample_df, repeated_df], axis=1)
combined
# Out:
#      Zip Code    Roll Year  Number of Buildings  Bathrooms  Square Footage  \
# 0       90001  2021.011143                    3          2             447
# 1       90002  2021.008335                    3          2             447
# 2       90003  2021.008422                    3          2             447
# 3       90004  2021.002186                    3          2             447
# 4       90005  2021.037239                    3          2             447
# ..        ...          ...                  ...        ...             ...
# 276     93551  2021.006554                    3          2             447
# 277     93552  2021.008169                    3          2             447
# 278     93553  2021.024806                    3          2             447
# 279     93563  2020.520833                    3          2             447
# 280     93591  2021.008736                    3          2             447
#
#      Number of Units  Property Type  Median Income  Housing Cost (%)  \
# 0                  2              3            324                40
# 1                  2              3            324                40
# 2                  2              3            324                40
# 3                  2              3            324                40
# 4                  2              3            324                40
# ..               ...            ...            ...               ...
# 276                2              3            324                40
# 277                2              3            324                40
# 278                2              3            324                40
# 279                2              3            324                40
# 280                2              3            324                40
#
#      Building Age  Improvement Value  Log_Improvement_Value  \
# 0              71                432               6.070738
# 1              71                432               6.070738
# 2              71                432               6.070738
# 3              71                432               6.070738
# 4              71                432               6.070738
# ..            ...                ...                    ...
# 276            71                432               6.070738
# 277            71                432               6.070738
# 278            71                432               6.070738
# 279            71                432               6.070738
# 280            71                432               6.070738
#
#      Log_Square_Footage
# 0              6.104793
# 1              6.104793
# 2              6.104793
# 3              6.104793
# 4              6.104793
# ..                  ...
# 276            6.104793
# 277            6.104793
# 278            6.104793
# 279            6.104793
# 280            6.104793
#
# [281 rows x 13 columns]

# %%
dataframe=combined.rename(columns={"Housing Cost (%)": "Housing Cost % of Income",
                          "Property Type": "Property Use Type Encoded"})

# %%
dataframe
# Out:
#      Zip Code    Roll Year  Number of Buildings  Bathrooms  Square Footage  \
# 0       90001  2021.011143                    3          2             447
# 1       90002  2021.008335                    3          2             447
# 2       90003  2021.008422                    3          2             447
# 3       90004  2021.002186                    3          2             447
# 4       90005  2021.037239                    3          2             447
# ..        ...          ...                  ...        ...             ...
# 276     93551  2021.006554                    3          2             447
# 277     93552  2021.008169                    3          2             447
# 278     93553  2021.024806                    3          2             447
# 279     93563  2020.520833                    3          2             447
# 280     93591  2021.008736                    3          2             447
#
#      Number of Units  Property Use Type Encoded  Median Income  \
# 0                  2                          3            324
# 1                  2                          3            324
# 2                  2                          3            324
# 3                  2                          3            324
# 4                  2                          3            324
# ..               ...                        ...            ...
# 276                2                          3            324
# 277                2                          3            324
# 278                2                          3            324
# 279                2                          3            324
# 280                2                          3            324
#
#      Housing Cost % of Income  Building Age  Improvement Value  \
# 0                          40            71                432
# 1                          40            71                432
# 2                          40            71                432
# 3                          40            71                432
# 4                          40            71                432
# ..                        ...           ...                ...
# 276                        40            71                432
# 277                        40            71                432
# 278                        40            71                432
# 279                        40            71                432
# 280                        40            71                432
#
#      Log_Improvement_Value  Log_Square_Footage
# 0                 6.070738            6.104793
# 1                 6.070738            6.104793
# 2                 6.070738            6.104793
# 3                 6.070738            6.104793
# 4                 6.070738            6.104793
# ..                     ...                 ...
# 276               6.070738            6.104793
# 277               6.070738            6.104793
# 278               6.070738            6.104793
# 279               6.070738            6.104793
# 280               6.070738            6.104793
#
# [281 rows x 13 columns]

# %%
feature_columns = [
    "Zip Code",
    "Roll Year",
    "Number of Buildings",
    "Bathrooms",
    "Number of Units",
    "Property Use Type Encoded",
    "Median Income",
    "Housing Cost % of Income",
    "Building Age",
    "Log_Improvement_Value",
    "Log_Square_Footage"
]

# %%
import joblib
model = joblib.load("lgbm_model_full.joblib")
categorical_cols = ["Zip Code", "Property Use Type Encoded"]
for col in categorical_cols:
    dataframe[col] = dataframe[col].astype("category")

predictions = model.predict(dataframe[feature_columns]) #predicts on dataframe 

# Display results
dataframe["Predicted Price"] = predictions
# print(test_data[["Zip Code", "Predicted Price"]])
dataframe
# Out:
#     Zip Code    Roll Year  Number of Buildings  Bathrooms  Square Footage  \
# 0      90001  2021.011143                    3          2             447
# 1      90002  2021.008335                    3          2             447
# 2      90003  2021.008422                    3          2             447
# 3      90004  2021.002186                    3          2             447
# 4      90005  2021.037239                    3          2             447
# ..       ...          ...                  ...        ...             ...
# 276    93551  2021.006554                    3          2             447
# 277    93552  2021.008169                    3          2             447
# 278    93553  2021.024806                    3          2             447
# 279    93563  2020.520833                    3          2             447
# 280    93591  2021.008736                    3          2             447
#
#      Number of Units Property Use Type Encoded  Median Income  \
# 0                  2                         3            324
# 1                  2                         3            324
# 2                  2                         3            324
# 3                  2                         3            324
# 4                  2                         3            324
# ..               ...                       ...            ...
# 276                2                         3            324
# 277                2                         3            324
# 278                2                         3            324
# 279                2                         3            324
# 280                2                         3            324
#
#      Housing Cost % of Income  Building Age  Improvement Value  \
# 0                          40            71                432
# 1                          40            71                432
# 2                          40            71                432
# 3                          40            71                432
# 4                          40            71                432
# ..                        ...           ...                ...
# 276                        40            71                432
# 277                        40            71                432
# 278                        40            71                432
# 279                        40            71                432
# 280                        40            71                432
#
#      Log_Improvement_Value  Log_Square_Footage  Predicted Price
# 0                 6.070738            6.104793        11.262228
# 1                 6.070738            6.104793        11.601475
# 2                 6.070738            6.104793        11.364162
# 3                 6.070738            6.104793        11.971738
# 4                 6.070738            6.104793        12.360485
# ..                     ...                 ...              ...
# 276               6.070738            6.104793        11.414935
# 277               6.070738            6.104793        10.843199
# 278               6.070738            6.104793        11.448421
# 279               6.070738            6.104793        11.448421
# 280               6.070738            6.104793        11.071691
#
# [281 rows x 14 columns]
